# %%
# !export PYTHONPATH=$PYTHONPATH:/datab/hungdx/KDW2V-AASISTL/fairseq

# %%
from teacher import *
from student import *
from wav2vec2_linear_nll_multi import Model as W2V2_LIN
import torch
from calflops import calculate_flops

device, xlsr_ssl_cpkt_path, ssl_cpkt_path = 'cuda', '/datad/hungdx/KDW2V-AASISTL/xlsr2_300m.pt', '/datad/hungdx/KDW2V-AASISTL/wav2vec_small.pt'
# XLSR-AASIST
m_t = W2V2_AASIST(device, xlsr_ssl_cpkt_path)
batch_size = 1
input_shape = (batch_size, 64600)

flops, macs, params = calculate_flops(model=m_t,
                                      input_shape=input_shape,
                                      output_as_string=True,
                                      output_precision=4)

print("Teacher(XLSR-AASIST): FLOPs:%s   MACs:%s   Params:%s \n" %
      (flops, macs, params))
m_s = Distil_W2V2BASE_AASISTL(device, ssl_cpkt_path)
flops, macs, params = calculate_flops(model=m_s,
                                      input_shape=input_shape,
                                      output_as_string=True,
                                      output_precision=4)

print("Student(W2V2BASE_AASIST-L): FLOPs:%s   MACs:%s   Params:%s \n" %
      (flops, macs, params))


# W2V2-BASE-Lin
m_t = W2V2_LIN(device, xlsr_ssl_cpkt_path)
flops, macs, params = calculate_flops(model=m_t,
                                      input_shape=input_shape,
                                      output_as_string=True,
                                      output_precision=4)
print("Teacher(XLSR-Linear):FLOPs:%s   MACs:%s   Params:%s \n" %
      (flops, macs, params))
m_s = Distil_W2V2BASE_Linear(device, ssl_cpkt_path)
flops, macs, params = calculate_flops(model=m_s,
                                      input_shape=input_shape,
                                      output_as_string=True,
                                      output_precision=4)

print("Student(W2V2BASE_Linear):FLOPs:%s   MACs:%s   Params:%s \n" %
      (flops, macs, params))
# Out:
# /home/hungdx/miniconda3/envs/KDW2V2-AASISTL/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# ------------------------------------- Calculate Flops Results -------------------------------------
# Notations:
# number of parameters (Params), number of multiply-accumulate operations(MACs),
# number of floating-point operations (FLOPs), floating-point operations per second (FLOPS),
# fwd FLOPs (model forward propagation FLOPs), bwd FLOPs (model backward propagation FLOPs),
# default model backpropagation takes 2.00 times as much computation as forward propagation.
#
# Total Training Params:                                                  317.84 M
# fwd MACs:                                                               73.4167 GMACs
# fwd FLOPs:                                                              147.004 GFLOPS
# fwd+bwd MACs:                                                           220.25 GMACs
# fwd+bwd FLOPs:                                                          441.012 GFLOPS
#
# -------------------------------- Detailed Calculated FLOPs Results --------------------------------
# Each module caculated is listed after its name in the following order:
# params, percentage of total params, MACs, percentage of total MACs, FLOPS, percentage of total FLOPs
#
# Note: 1. A module can have torch.nn.module or torch.nn.functional to compute logits (e.g. CrossEntropyLoss).
#  They are not counted as submodules in calflops and not to be printed out. However they make up the difference between a parent's MACs and the sum of its submodules'.
# 2. Number of floating-point operations is a theoretical estimation, thus FLOPS computed using that could be larger than the maximum system throughput.
#
# W2V2_AASIST(
#   317.84 M = 100% Params, 73.42 GMACs = 100% MACs, 147 GFLOPS = 49.9419% FLOPs
#   (ssl_model): SSLModel(
#     317.39 M = 99.8593% Params, 72.71 GMACs = 99.033% MACs, 145.58 GFLOPS = 49.459% FLOPs
#     (model): Wav2Vec2Model(
#       317.39 M = 99.8593% Params, 72.71 GMACs = 99.033% MACs, 145.58 GFLOPS = 49.459% FLOPs
#       (feature_extractor): ConvFeatureExtractionModel(
#         4.21 M = 1.3246% Params, 9.9 GMACs = 13.4914% MACs, 19.9 GFLOPS = 6.7379% FLOPs
#         (conv_layers): ModuleList(
#           (0): Sequential(
#             6.66 K = 0.0021% Params, 66.15 MMACs = 0.0901% MACs, 178.59 MFLOPS = 0.045% FLOPs
#             (0): Conv1d(5.63 K = 0.0018% Params, 66.15 MMACs = 0.0901% MACs, 138.91 MFLOPS = 0.045% FLOPs, 1, 512, kernel_size=(10,), stride=(5,))
#             (1): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.0, inplace=False)
#             (2): Sequential(
#               1.02 K = 0.0003% Params, 0 MACs = 0% MACs, 33.07 MFLOPS = 0% FLOPs
#               (0): TransposeLast(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#               (1): Fp32LayerNorm(1.02 K = 0.0003% Params, 0 MACs = 0% MACs, 33.07 MFLOPS = 0% FLOPs, (512,), eps=1e-05, elementwise_affine=True)
#               (2): TransposeLast(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#             )
#             (3): GELU(0 = 0% Params, 0 MACs = 0% MACs, 6.61 MFLOPS = 0% FLOPs, approximate='none')
#           )
#           (1): Sequential(
#             787.97 K = 0.2479% Params, 5.08 GMACs = 6.9188% MACs, 10.18 GFLOPS = 3.4554% FLOPs
#             (0): Conv1d(786.94 K = 0.2476% Params, 5.08 GMACs = 6.9188% MACs, 10.16 GFLOPS = 3.4554% FLOPs, 512, 512, kernel_size=(3,), stride=(2,))
#             (1): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.0, inplace=False)
#             (2): Sequential(
#               1.02 K = 0.0003% Params, 0 MACs = 0% MACs, 16.54 MFLOPS = 0% FLOPs
#               (0): TransposeLast(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#               (1): Fp32LayerNorm(1.02 K = 0.0003% Params, 0 MACs = 0% MACs, 16.54 MFLOPS = 0% FLOPs, (512,), eps=1e-05, elementwise_affine=True)
#               (2): TransposeLast(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#             )
#             (3): GELU(0 = 0% Params, 0 MACs = 0% MACs, 3.31 MFLOPS = 0% FLOPs, approximate='none')
#           )
#           (2): Sequential(
#             787.97 K = 0.2479% Params, 2.54 GMACs = 3.4589% MACs, 5.09 GFLOPS = 1.7274% FLOPs
#             (0): Conv1d(786.94 K = 0.2476% Params, 2.54 GMACs = 3.4589% MACs, 5.08 GFLOPS = 1.7274% FLOPs, 512, 512, kernel_size=(3,), stride=(2,))
#             (1): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.0, inplace=False)
#             (2): Sequential(
#               1.02 K = 0.0003% Params, 0 MACs = 0% MACs, 8.27 MFLOPS = 0% FLOPs
#               (0): TransposeLast(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#               (1): Fp32LayerNorm(1.02 K = 0.0003% Params, 0 MACs = 0% MACs, 8.27 MFLOPS = 0% FLOPs, (512,), eps=1e-05, elementwise_affine=True)
#               (2): TransposeLast(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#             )
#             (3): GELU(0 = 0% Params, 0 MACs = 0% MACs, 1.65 MFLOPS = 0% FLOPs, approximate='none')
#           )
#           (3): Sequential(
#             787.97 K = 0.2479% Params, 1.27 GMACs = 1.7289% MACs, 2.54 GFLOPS = 0.8634% FLOPs
#             (0): Conv1d(786.94 K = 0.2476% Params, 1.27 GMACs = 1.7289% MACs, 2.54 GFLOPS = 0.8634% FLOPs, 512, 512, kernel_size=(3,), stride=(2,))
#             (1): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.0, inplace=False)
#             (2): Sequential(
#               1.02 K = 0.0003% Params, 0 MACs = 0% MACs, 4.13 MFLOPS = 0% FLOPs
#               (0): TransposeLast(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#               (1): Fp32LayerNorm(1.02 K = 0.0003% Params, 0 MACs = 0% MACs, 4.13 MFLOPS = 0% FLOPs, (512,), eps=1e-05, elementwise_affine=True)
#               (2): TransposeLast(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#             )
#             (3): GELU(0 = 0% Params, 0 MACs = 0% MACs, 826.37 KFLOPS = 0% FLOPs, approximate='none')
#           )
#           (4): Sequential(
#             787.97 K = 0.2479% Params, 633.86 MMACs = 0.8634% MACs, 1.27 GFLOPS = 0.4312% FLOPs
#             (0): Conv1d(786.94 K = 0.2476% Params, 633.86 MMACs = 0.8634% MACs, 1.27 GFLOPS = 0.4312% FLOPs, 512, 512, kernel_size=(3,), stride=(2,))
#             (1): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.0, inplace=False)
#             (2): Sequential(
#               1.02 K = 0.0003% Params, 0 MACs = 0% MACs, 2.06 MFLOPS = 0% FLOPs
#               (0): TransposeLast(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#               (1): Fp32LayerNorm(1.02 K = 0.0003% Params, 0 MACs = 0% MACs, 2.06 MFLOPS = 0% FLOPs, (512,), eps=1e-05, elementwise_affine=True)
#               (2): TransposeLast(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#             )
#             (3): GELU(0 = 0% Params, 0 MACs = 0% MACs, 412.67 KFLOPS = 0% FLOPs, approximate='none')
#           )
#           (5): Sequential(
#             525.82 K = 0.1654% Params, 211.29 MMACs = 0.2878% MACs, 424.02 MFLOPS = 0.1437% FLOPs
#             (0): Conv1d(524.8 K = 0.1651% Params, 211.29 MMACs = 0.2878% MACs, 422.78 MFLOPS = 0.1437% FLOPs, 512, 512, kernel_size=(2,), stride=(2,))
#             (1): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.0, inplace=False)
#             (2): Sequential(
#               1.02 K = 0.0003% Params, 0 MACs = 0% MACs, 1.03 MFLOPS = 0% FLOPs
#               (0): TransposeLast(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#               (1): Fp32LayerNorm(1.02 K = 0.0003% Params, 0 MACs = 0% MACs, 1.03 MFLOPS = 0% FLOPs, (512,), eps=1e-05, elementwise_affine=True)
#               (2): TransposeLast(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#             )
#             (3): GELU(0 = 0% Params, 0 MACs = 0% MACs, 206.34 KFLOPS = 0% FLOPs, approximate='none')
#           )
#           (6): Sequential(
#             525.82 K = 0.1654% Params, 105.38 MMACs = 0.1435% MACs, 211.48 MFLOPS = 0.0717% FLOPs
#             (0): Conv1d(524.8 K = 0.1651% Params, 105.38 MMACs = 0.1435% MACs, 210.87 MFLOPS = 0.0717% FLOPs, 512, 512, kernel_size=(2,), stride=(2,))
#             (1): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.0, inplace=False)
#             (2): Sequential(
#               1.02 K = 0.0003% Params, 0 MACs = 0% MACs, 514.56 KFLOPS = 0% FLOPs
#               (0): TransposeLast(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#               (1): Fp32LayerNorm(1.02 K = 0.0003% Params, 0 MACs = 0% MACs, 514.56 KFLOPS = 0% FLOPs, (512,), eps=1e-05, elementwise_affine=True)
#               (2): TransposeLast(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#             )
#             (3): GELU(0 = 0% Params, 0 MACs = 0% MACs, 102.91 KFLOPS = 0% FLOPs, approximate='none')
#           )
#         )
#       )
#       (post_extract_proj): Linear(525.31 K = 0.1653% Params, 105.38 MMACs = 0.1435% MACs, 210.76 MFLOPS = 0.0717% FLOPs, in_features=512, out_features=1024, bias=True)
#       (dropout_input): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.0, inplace=False)
#       (dropout_features): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.0, inplace=False)
#       (quantizer): GumbelVectorQuantizer(
#         574.08 K = 0.1806% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs
#         (weight_proj): Linear(328.32 K = 0.1033% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, in_features=512, out_features=640, bias=True)
#       )
#       (project_q): Linear(590.59 K = 0.1858% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, in_features=768, out_features=768, bias=True)
#       (encoder): TransformerEncoder(
#         310.7 M = 97.7546% Params, 62.7 GMACs = 85.3981% MACs, 125.46 GFLOPS = 42.6495% FLOPs
#         (pos_conv): Sequential(
#           8.39 M = 2.6396% Params, 1.69 GMACs = 2.3081% MACs, 3.39 GFLOPS = 1.1527% FLOPs
#           (0): Conv1d(8.39 M = 2.6396% Params, 1.69 GMACs = 2.3081% MACs, 3.39 GFLOPS = 1.1527% FLOPs, 1024, 1024, kernel_size=(128,), stride=(1,), padding=(64,), groups=16)
#           (1): SamePad(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (2): GELU(0 = 0% Params, 0 MACs = 0% MACs, 205.82 KFLOPS = 0% FLOPs, approximate='none')
#         )
#         (layers): ModuleList(
#           (0-23): 24 x TransformerSentenceEncoderLayer(
#             12.6 M = 3.9631% Params, 2.54 GMACs = 3.4621% MACs, 5.09 GFLOPS = 1.729% FLOPs
#             (self_attn): MultiheadAttention(
#               4.2 M = 1.3209% Params, 847.25 MMACs = 1.154% MACs, 1.69 GFLOPS = 0.5763% FLOPs
#               (dropout_module): FairseqDropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#               (k_proj): Linear(1.05 M = 0.3302% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(1.05 M = 0.3302% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(1.05 M = 0.3302% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(1.05 M = 0.3302% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, in_features=1024, out_features=1024, bias=True)
#             )
#             (dropout1): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.0, inplace=False)
#             (dropout2): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.0, inplace=False)
#             (dropout3): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.0, inplace=False)
#             (self_attn_layer_norm): LayerNorm(2.05 K = 0.0006% Params, 0 MACs = 0% MACs, 1.03 MFLOPS = 0% FLOPs, (1024,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(4.2 M = 1.3209% Params, 847.25 MMACs = 1.154% MACs, 1.69 GFLOPS = 0.5763% FLOPs, in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(4.2 M = 1.32% Params, 847.25 MMACs = 1.154% MACs, 1.69 GFLOPS = 0.5763% FLOPs, in_features=4096, out_features=1024, bias=True)
#             (final_layer_norm): LayerNorm(2.05 K = 0.0006% Params, 0 MACs = 0% MACs, 1.03 MFLOPS = 0% FLOPs, (1024,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (layer_norm): LayerNorm(2.05 K = 0.0006% Params, 0 MACs = 0% MACs, 1.03 MFLOPS = 0% FLOPs, (1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (layer_norm): LayerNorm(1.02 K = 0.0003% Params, 0 MACs = 0% MACs, 514.56 KFLOPS = 0% FLOPs, (512,), eps=1e-05, elementwise_affine=True)
#       (final_proj): Linear(787.2 K = 0.2477% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, in_features=1024, out_features=768, bias=True)
#     )
#   )
#   (LL): Linear(131.2 K = 0.0413% Params, 26.35 MMACs = 0.0359% MACs, 52.69 MFLOPS = 0.0179% FLOPs, in_features=1024, out_features=128, bias=True)
#   (first_bn): BatchNorm2d(2 = 0% Params, 0 MACs = 0% MACs, 5.63 KFLOPS = 0% FLOPs, 1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (first_bn1): BatchNorm2d(128 = 0% Params, 0 MACs = 0% MACs, 360.19 KFLOPS = 0% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.5, inplace=True)
#   (drop_way): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.2, inplace=True)
#   (selu): SELU(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#   (encoder): Sequential(
#     211.07 K = 0.0664% Params, 594.83 MMACs = 0.8102% MACs, 1.2 GFLOPS = 0.4046% FLOPs
#     (0): Sequential(
#       6.59 K = 0.0021% Params, 18.11 MMACs = 0.0247% MACs, 36.68 MFLOPS = 0.0123% FLOPs
#       (0): Residual_block(
#         6.59 K = 0.0021% Params, 18.11 MMACs = 0.0247% MACs, 36.68 MFLOPS = 0.0123% FLOPs
#         (conv1): Conv2d(224 = 0.0001% Params, 553.15 KMACs = 0.0008% MACs, 1.2 MFLOPS = 0.0004% FLOPs, 1, 32, kernel_size=(2, 3), stride=(1, 1), padding=(1, 1))
#         (selu): SELU(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         (bn2): BatchNorm2d(64 = 0% Params, 0 MACs = 0% MACs, 184.38 KFLOPS = 0% FLOPs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(6.18 K = 0.0019% Params, 17.29 MMACs = 0.0235% MACs, 34.67 MFLOPS = 0.0118% FLOPs, 32, 32, kernel_size=(2, 3), stride=(1, 1), padding=(0, 1))
#         (conv_downsample): Conv2d(128 = 0% Params, 270.14 KMACs = 0.0004% MACs, 630.34 KFLOPS = 0.0002% FLOPs, 1, 32, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#       )
#     )
#     (1): Sequential(
#       12.48 K = 0.0039% Params, 34.99 MMACs = 0.0477% MACs, 70.53 MFLOPS = 0.0238% FLOPs
#       (0): Residual_block(
#         12.48 K = 0.0039% Params, 34.99 MMACs = 0.0477% MACs, 70.53 MFLOPS = 0.0238% FLOPs
#         (bn1): BatchNorm2d(64 = 0% Params, 0 MACs = 0% MACs, 180.1 KFLOPS = 0% FLOPs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(6.18 K = 0.0019% Params, 17.7 MMACs = 0.0241% MACs, 35.49 MFLOPS = 0.012% FLOPs, 32, 32, kernel_size=(2, 3), stride=(1, 1), padding=(1, 1))
#         (selu): SELU(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         (bn2): BatchNorm2d(64 = 0% Params, 0 MACs = 0% MACs, 184.38 KFLOPS = 0% FLOPs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(6.18 K = 0.0019% Params, 17.29 MMACs = 0.0235% MACs, 34.67 MFLOPS = 0.0118% FLOPs, 32, 32, kernel_size=(2, 3), stride=(1, 1), padding=(0, 1))
#       )
#     )
#     (2): Sequential(
#       43.39 K = 0.0137% Params, 121.85 MMACs = 0.166% MACs, 244.79 MFLOPS = 0.0829% FLOPs
#       (0): Residual_block(
#         43.39 K = 0.0137% Params, 121.85 MMACs = 0.166% MACs, 244.79 MFLOPS = 0.0829% FLOPs
#         (bn1): BatchNorm2d(64 = 0% Params, 0 MACs = 0% MACs, 180.1 KFLOPS = 0% FLOPs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(12.35 K = 0.0039% Params, 35.4 MMACs = 0.0482% MACs, 70.99 MFLOPS = 0.0241% FLOPs, 32, 64, kernel_size=(2, 3), stride=(1, 1), padding=(1, 1))
#         (selu): SELU(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         (bn2): BatchNorm2d(128 = 0% Params, 0 MACs = 0% MACs, 368.77 KFLOPS = 0% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(24.64 K = 0.0078% Params, 69.16 MMACs = 0.0942% MACs, 138.49 MFLOPS = 0.047% FLOPs, 64, 64, kernel_size=(2, 3), stride=(1, 1), padding=(0, 1))
#         (conv_downsample): Conv2d(6.21 K = 0.002% Params, 17.29 MMACs = 0.0235% MACs, 34.76 MFLOPS = 0.0118% FLOPs, 32, 64, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#       )
#     )
#     (3): Sequential(
#       49.54 K = 0.0156% Params, 139.96 MMACs = 0.1906% MACs, 281.01 MFLOPS = 0.0952% FLOPs
#       (0): Residual_block(
#         49.54 K = 0.0156% Params, 139.96 MMACs = 0.1906% MACs, 281.01 MFLOPS = 0.0952% FLOPs
#         (bn1): BatchNorm2d(128 = 0% Params, 0 MACs = 0% MACs, 360.19 KFLOPS = 0% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(24.64 K = 0.0078% Params, 70.8 MMACs = 0.0964% MACs, 141.79 MFLOPS = 0.0482% FLOPs, 64, 64, kernel_size=(2, 3), stride=(1, 1), padding=(1, 1))
#         (selu): SELU(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         (bn2): BatchNorm2d(128 = 0% Params, 0 MACs = 0% MACs, 368.77 KFLOPS = 0% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(24.64 K = 0.0078% Params, 69.16 MMACs = 0.0942% MACs, 138.49 MFLOPS = 0.047% FLOPs, 64, 64, kernel_size=(2, 3), stride=(1, 1), padding=(0, 1))
#       )
#     )
#     (4): Sequential(
#       49.54 K = 0.0156% Params, 139.96 MMACs = 0.1906% MACs, 281.01 MFLOPS = 0.0952% FLOPs
#       (0): Residual_block(
#         49.54 K = 0.0156% Params, 139.96 MMACs = 0.1906% MACs, 281.01 MFLOPS = 0.0952% FLOPs
#         (bn1): BatchNorm2d(128 = 0% Params, 0 MACs = 0% MACs, 360.19 KFLOPS = 0% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(24.64 K = 0.0078% Params, 70.8 MMACs = 0.0964% MACs, 141.79 MFLOPS = 0.0482% FLOPs, 64, 64, kernel_size=(2, 3), stride=(1, 1), padding=(1, 1))
#         (selu): SELU(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         (bn2): BatchNorm2d(128 = 0% Params, 0 MACs = 0% MACs, 368.77 KFLOPS = 0% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(24.64 K = 0.0078% Params, 69.16 MMACs = 0.0942% MACs, 138.49 MFLOPS = 0.047% FLOPs, 64, 64, kernel_size=(2, 3), stride=(1, 1), padding=(0, 1))
#       )
#     )
#     (5): Sequential(
#       49.54 K = 0.0156% Params, 139.96 MMACs = 0.1906% MACs, 281.01 MFLOPS = 0.0952% FLOPs
#       (0): Residual_block(
#         49.54 K = 0.0156% Params, 139.96 MMACs = 0.1906% MACs, 281.01 MFLOPS = 0.0952% FLOPs
#         (bn1): BatchNorm2d(128 = 0% Params, 0 MACs = 0% MACs, 360.19 KFLOPS = 0% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(24.64 K = 0.0078% Params, 70.8 MMACs = 0.0964% MACs, 141.79 MFLOPS = 0.0482% FLOPs, 64, 64, kernel_size=(2, 3), stride=(1, 1), padding=(1, 1))
#         (selu): SELU(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         (bn2): BatchNorm2d(128 = 0% Params, 0 MACs = 0% MACs, 368.77 KFLOPS = 0% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(24.64 K = 0.0078% Params, 69.16 MMACs = 0.0942% MACs, 138.49 MFLOPS = 0.047% FLOPs, 64, 64, kernel_size=(2, 3), stride=(1, 1), padding=(0, 1))
#       )
#     )
#   )
#   (attention): Sequential(
#     16.83 K = 0.0053% Params, 46.1 MMACs = 0.0628% MACs, 93.47 MFLOPS = 0.0314% FLOPs
#     (0): Conv2d(8.32 K = 0.0026% Params, 23.05 MMACs = 0.0314% MACs, 46.46 MFLOPS = 0.0157% FLOPs, 64, 128, kernel_size=(1, 1), stride=(1, 1))
#     (1): SELU(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#     (2): BatchNorm2d(256 = 0.0001% Params, 0 MACs = 0% MACs, 720.38 KFLOPS = 0% FLOPs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(8.26 K = 0.0026% Params, 23.05 MMACs = 0.0314% MACs, 46.28 MFLOPS = 0.0157% FLOPs, 128, 64, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (GAT_layer_S): GraphAttentionLayer(
#     12.67 K = 0.004% Params, 7.8 MMACs = 0.0106% MACs, 15.6 MFLOPS = 0.0053% FLOPs
#     (att_proj): Linear(4.16 K = 0.0013% Params, 7.23 MMACs = 0.0098% MACs, 14.45 MFLOPS = 0.0049% FLOPs, in_features=64, out_features=64, bias=True)
#     (proj_with_att): Linear(4.16 K = 0.0013% Params, 172.03 KMACs = 0.0002% MACs, 344.06 KFLOPS = 0.0001% FLOPs, in_features=64, out_features=64, bias=True)
#     (proj_without_att): Linear(4.16 K = 0.0013% Params, 172.03 KMACs = 0.0002% MACs, 344.06 KFLOPS = 0.0001% FLOPs, in_features=64, out_features=64, bias=True)
#     (bn): BatchNorm1d(128 = 0% Params, 0 MACs = 0% MACs, 5.38 KFLOPS = 0% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (input_drop): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.2, inplace=False)
#     (act): SELU(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#   )
#   (GAT_layer_T): GraphAttentionLayer(
#     12.67 K = 0.004% Params, 19.51 MMACs = 0.0266% MACs, 39.03 MFLOPS = 0.0133% FLOPs
#     (att_proj): Linear(4.16 K = 0.0013% Params, 18.39 MMACs = 0.025% MACs, 36.77 MFLOPS = 0.0125% FLOPs, in_features=64, out_features=64, bias=True)
#     (proj_with_att): Linear(4.16 K = 0.0013% Params, 274.43 KMACs = 0.0004% MACs, 548.86 KFLOPS = 0.0002% FLOPs, in_features=64, out_features=64, bias=True)
#     (proj_without_att): Linear(4.16 K = 0.0013% Params, 274.43 KMACs = 0.0004% MACs, 548.86 KFLOPS = 0.0002% FLOPs, in_features=64, out_features=64, bias=True)
#     (bn): BatchNorm1d(128 = 0% Params, 0 MACs = 0% MACs, 8.58 KFLOPS = 0% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (input_drop): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.2, inplace=False)
#     (act): SELU(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#   )
#   (HtrgGAT_layer_ST11): HtrgGraphAttentionLayer(
#     20.99 K = 0.0066% Params, 6.81 MMACs = 0.0093% MACs, 13.63 MFLOPS = 0.0046% FLOPs
#     (proj_type1): Linear(4.16 K = 0.0013% Params, 135.17 KMACs = 0.0002% MACs, 270.34 KFLOPS = 0.0001% FLOPs, in_features=64, out_features=64, bias=True)
#     (proj_type2): Linear(4.16 K = 0.0013% Params, 86.02 KMACs = 0.0001% MACs, 172.03 KFLOPS = 0.0001% FLOPs, in_features=64, out_features=64, bias=True)
#     (att_proj): Linear(2.08 K = 0.0007% Params, 5.97 MMACs = 0.0081% MACs, 11.94 MFLOPS = 0.0041% FLOPs, in_features=64, out_features=32, bias=True)
#     (att_projM): Linear(2.08 K = 0.0007% Params, 110.59 KMACs = 0.0002% MACs, 221.18 KFLOPS = 0.0001% FLOPs, in_features=64, out_features=32, bias=True)
#     (proj_with_att): Linear(2.08 K = 0.0007% Params, 110.59 KMACs = 0.0002% MACs, 221.18 KFLOPS = 0.0001% FLOPs, in_features=64, out_features=32, bias=True)
#     (proj_without_att): Linear(2.08 K = 0.0007% Params, 110.59 KMACs = 0.0002% MACs, 221.18 KFLOPS = 0.0001% FLOPs, in_features=64, out_features=32, bias=True)
#     (proj_with_attM): Linear(2.08 K = 0.0007% Params, 2.05 KMACs = 0% MACs, 4.1 KFLOPS = 0% FLOPs, in_features=64, out_features=32, bias=True)
#     (proj_without_attM): Linear(2.08 K = 0.0007% Params, 2.05 KMACs = 0% MACs, 4.1 KFLOPS = 0% FLOPs, in_features=64, out_features=32, bias=True)
#     (bn): BatchNorm1d(64 = 0% Params, 0 MACs = 0% MACs, 3.46 KFLOPS = 0% FLOPs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (input_drop): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.2, inplace=False)
#     (act): SELU(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#   )
#   (HtrgGAT_layer_ST12): HtrgGraphAttentionLayer(
#     8.64 K = 0.0027% Params, 845.7 KMACs = 0.0012% MACs, 1.69 MFLOPS = 0.0006% FLOPs
#     (proj_type1): Linear(1.06 K = 0.0003% Params, 16.38 KMACs = 0% MACs, 32.77 KFLOPS = 0% FLOPs, in_features=32, out_features=32, bias=True)
#     (proj_type2): Linear(1.06 K = 0.0003% Params, 10.24 KMACs = 0% MACs, 20.48 KFLOPS = 0% FLOPs, in_features=32, out_features=32, bias=True)
#     (att_proj): Linear(1.06 K = 0.0003% Params, 692.22 KMACs = 0.0009% MACs, 1.38 MFLOPS = 0.0005% FLOPs, in_features=32, out_features=32, bias=True)
#     (att_projM): Linear(1.06 K = 0.0003% Params, 26.62 KMACs = 0% MACs, 53.25 KFLOPS = 0% FLOPs, in_features=32, out_features=32, bias=True)
#     (proj_with_att): Linear(1.06 K = 0.0003% Params, 26.62 KMACs = 0% MACs, 53.25 KFLOPS = 0% FLOPs, in_features=32, out_features=32, bias=True)
#     (proj_without_att): Linear(1.06 K = 0.0003% Params, 26.62 KMACs = 0% MACs, 53.25 KFLOPS = 0% FLOPs, in_features=32, out_features=32, bias=True)
#     (proj_with_attM): Linear(1.06 K = 0.0003% Params, 1.02 KMACs = 0% MACs, 2.05 KFLOPS = 0% FLOPs, in_features=32, out_features=32, bias=True)
#     (proj_without_attM): Linear(1.06 K = 0.0003% Params, 1.02 KMACs = 0% MACs, 2.05 KFLOPS = 0% FLOPs, in_features=32, out_features=32, bias=True)
#     (bn): BatchNorm1d(64 = 0% Params, 0 MACs = 0% MACs, 1.66 KFLOPS = 0% FLOPs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (input_drop): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.2, inplace=False)
#     (act): SELU(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#   )
#   (HtrgGAT_layer_ST21): HtrgGraphAttentionLayer(
#     20.99 K = 0.0066% Params, 6.81 MMACs = 0.0093% MACs, 13.63 MFLOPS = 0.0046% FLOPs
#     (proj_type1): Linear(4.16 K = 0.0013% Params, 135.17 KMACs = 0.0002% MACs, 270.34 KFLOPS = 0.0001% FLOPs, in_features=64, out_features=64, bias=True)
#     (proj_type2): Linear(4.16 K = 0.0013% Params, 86.02 KMACs = 0.0001% MACs, 172.03 KFLOPS = 0.0001% FLOPs, in_features=64, out_features=64, bias=True)
#     (att_proj): Linear(2.08 K = 0.0007% Params, 5.97 MMACs = 0.0081% MACs, 11.94 MFLOPS = 0.0041% FLOPs, in_features=64, out_features=32, bias=True)
#     (att_projM): Linear(2.08 K = 0.0007% Params, 110.59 KMACs = 0.0002% MACs, 221.18 KFLOPS = 0.0001% FLOPs, in_features=64, out_features=32, bias=True)
#     (proj_with_att): Linear(2.08 K = 0.0007% Params, 110.59 KMACs = 0.0002% MACs, 221.18 KFLOPS = 0.0001% FLOPs, in_features=64, out_features=32, bias=True)
#     (proj_without_att): Linear(2.08 K = 0.0007% Params, 110.59 KMACs = 0.0002% MACs, 221.18 KFLOPS = 0.0001% FLOPs, in_features=64, out_features=32, bias=True)
#     (proj_with_attM): Linear(2.08 K = 0.0007% Params, 2.05 KMACs = 0% MACs, 4.1 KFLOPS = 0% FLOPs, in_features=64, out_features=32, bias=True)
#     (proj_without_attM): Linear(2.08 K = 0.0007% Params, 2.05 KMACs = 0% MACs, 4.1 KFLOPS = 0% FLOPs, in_features=64, out_features=32, bias=True)
#     (bn): BatchNorm1d(64 = 0% Params, 0 MACs = 0% MACs, 3.46 KFLOPS = 0% FLOPs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (input_drop): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.2, inplace=False)
#     (act): SELU(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#   )
#   (HtrgGAT_layer_ST22): HtrgGraphAttentionLayer(
#     8.64 K = 0.0027% Params, 845.7 KMACs = 0.0012% MACs, 1.69 MFLOPS = 0.0006% FLOPs
#     (proj_type1): Linear(1.06 K = 0.0003% Params, 16.38 KMACs = 0% MACs, 32.77 KFLOPS = 0% FLOPs, in_features=32, out_features=32, bias=True)
#     (proj_type2): Linear(1.06 K = 0.0003% Params, 10.24 KMACs = 0% MACs, 20.48 KFLOPS = 0% FLOPs, in_features=32, out_features=32, bias=True)
#     (att_proj): Linear(1.06 K = 0.0003% Params, 692.22 KMACs = 0.0009% MACs, 1.38 MFLOPS = 0.0005% FLOPs, in_features=32, out_features=32, bias=True)
#     (att_projM): Linear(1.06 K = 0.0003% Params, 26.62 KMACs = 0% MACs, 53.25 KFLOPS = 0% FLOPs, in_features=32, out_features=32, bias=True)
#     (proj_with_att): Linear(1.06 K = 0.0003% Params, 26.62 KMACs = 0% MACs, 53.25 KFLOPS = 0% FLOPs, in_features=32, out_features=32, bias=True)
#     (proj_without_att): Linear(1.06 K = 0.0003% Params, 26.62 KMACs = 0% MACs, 53.25 KFLOPS = 0% FLOPs, in_features=32, out_features=32, bias=True)
#     (proj_with_attM): Linear(1.06 K = 0.0003% Params, 1.02 KMACs = 0% MACs, 2.05 KFLOPS = 0% FLOPs, in_features=32, out_features=32, bias=True)
#     (proj_without_attM): Linear(1.06 K = 0.0003% Params, 1.02 KMACs = 0% MACs, 2.05 KFLOPS = 0% FLOPs, in_features=32, out_features=32, bias=True)
#     (bn): BatchNorm1d(64 = 0% Params, 0 MACs = 0% MACs, 1.66 KFLOPS = 0% FLOPs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (input_drop): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.2, inplace=False)
#     (act): SELU(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#   )
#   (pool_S): GraphPool(
#     65 = 0% Params, 2.69 KMACs = 0% MACs, 5.38 KFLOPS = 0% FLOPs
#     (sigmoid): Sigmoid(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#     (proj): Linear(65 = 0% Params, 2.69 KMACs = 0% MACs, 5.38 KFLOPS = 0% FLOPs, in_features=64, out_features=1, bias=True)
#     (drop): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.3, inplace=False)
#   )
#   (pool_T): GraphPool(
#     65 = 0% Params, 4.29 KMACs = 0% MACs, 8.58 KFLOPS = 0% FLOPs
#     (sigmoid): Sigmoid(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#     (proj): Linear(65 = 0% Params, 4.29 KMACs = 0% MACs, 8.58 KFLOPS = 0% FLOPs, in_features=64, out_features=1, bias=True)
#     (drop): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.3, inplace=False)
#   )
#   (pool_hS1): GraphPool(
#     33 = 0% Params, 672 MACs = 0% MACs, 1.34 KFLOPS = 0% FLOPs
#     (sigmoid): Sigmoid(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#     (proj): Linear(33 = 0% Params, 672 MACs = 0% MACs, 1.34 KFLOPS = 0% FLOPs, in_features=32, out_features=1, bias=True)
#     (drop): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.3, inplace=False)
#   )
#   (pool_hT1): GraphPool(
#     33 = 0% Params, 1.06 KMACs = 0% MACs, 2.11 KFLOPS = 0% FLOPs
#     (sigmoid): Sigmoid(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#     (proj): Linear(33 = 0% Params, 1.06 KMACs = 0% MACs, 2.11 KFLOPS = 0% FLOPs, in_features=32, out_features=1, bias=True)
#     (drop): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.3, inplace=False)
#   )
#   (pool_hS2): GraphPool(
#     33 = 0% Params, 672 MACs = 0% MACs, 1.34 KFLOPS = 0% FLOPs
#     (sigmoid): Sigmoid(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#     (proj): Linear(33 = 0% Params, 672 MACs = 0% MACs, 1.34 KFLOPS = 0% FLOPs, in_features=32, out_features=1, bias=True)
#     (drop): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.3, inplace=False)
#   )
#   (pool_hT2): GraphPool(
#     33 = 0% Params, 1.06 KMACs = 0% MACs, 2.11 KFLOPS = 0% FLOPs
#     (sigmoid): Sigmoid(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#     (proj): Linear(33 = 0% Params, 1.06 KMACs = 0% MACs, 2.11 KFLOPS = 0% FLOPs, in_features=32, out_features=1, bias=True)
#     (drop): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.3, inplace=False)
#   )
#   (out_layer): Linear(322 = 0.0001% Params, 320 MACs = 0% MACs, 640 FLOPS = 0% FLOPs, in_features=160, out_features=2, bias=True)
# )
# ---------------------------------------------------------------------------------------------------
# Teacher(XLSR-AASIST): FLOPs:147.004 GFLOPS   MACs:73.4167 GMACs   Params:317.838 M
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 20
#      13 flops, macs, params = calculate_flops(model=m_t,
#      14                                       input_shape=input_shape,
#      15                                       output_as_string=True,
#      16                                       output_precision=4)
#      18 print("Teacher(XLSR-AASIST): FLOPs:%s   MACs:%s   Params:%s \n" %
#      19       (flops, macs, params))
# ---> 20 m_s = Distil_W2V2BASE_AASISTL(device, ssl_cpkt_path)
#      21 flops, macs, params = calculate_flops(model=m_s,
#      22                                       input_shape=input_shape,
#      23                                       output_as_string=True,
#      24                                       output_precision=4)
#      26 print("Student(W2V2BASE_AASIST-L): FLOPs:%s   MACs:%s   Params:%s \n" %
#      27       (flops, macs, params))
#
# File /datad/hungdx/KDW2V-AASISTL/student.py:3007, in Distil_W2V2BASE_AASISTL.__init__(self, device, ssl_cpkt_path)
#    3002 temperatures = [2.0, 2.0, 100.0, 100.0]
#    3004 ####
#    3005 # create network wav2vec 2.0
#    3006 ####
# -> 3007 self.ssl_model = SSLModel(device, ssl_cpkt_path, 768).to(device)
#    3008 self.LL = nn.Linear(self.ssl_model.out_dim, 128)
#    3009 self.first_bn = nn.BatchNorm2d(num_features=1)
#
# File /datad/hungdx/KDW2V-AASISTL/models.py:202, in SSLModel.__init__(self, device, cp_path, out_dim)
#     200 def __init__(self, device, cp_path, out_dim):
#     201     super().__init__()
# --> 202     model, cfg, task = fairseq.checkpoint_utils.load_model_ensemble_and_task([
#     203                                                                              cp_path])
#     204     self.model = model[0]
#     205     self.model = self.model.to(device)
#
# File /datab/hungdx/KDW2V-AASISTL/fairseq/fairseq/checkpoint_utils.py:450, in load_model_ensemble_and_task(filenames, arg_overrides, task, strict, suffix, num_shards, state)
#     448     raise IOError("Model file not found: {}".format(filename))
#     449 if state is None:
# --> 450     state = load_checkpoint_to_cpu(filename, arg_overrides)
#     451 if "args" in state and state["args"] is not None:
#     452     cfg = convert_namespace_to_omegaconf(state["args"])
#
# File /datab/hungdx/KDW2V-AASISTL/fairseq/fairseq/checkpoint_utils.py:340, in load_checkpoint_to_cpu(path, arg_overrides, load_on_all_ranks)
#     337     local_path = PathManager.get_local_path(path)
#     339 with open(local_path, "rb") as f:
# --> 340     state = torch.load(f, map_location=torch.device("cpu"))
#     342 if "args" in state and state["args"] is not None and arg_overrides is not None:
#     343     args = state["args"]
#
# File ~/miniconda3/envs/KDW2V2-AASISTL/lib/python3.10/site-packages/torch/serialization.py:1028, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1026     except RuntimeError as e:
#    1027         raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# -> 1028 return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#
# File ~/miniconda3/envs/KDW2V2-AASISTL/lib/python3.10/site-packages/torch/serialization.py:1256, in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#    1254 unpickler = UnpicklerWrapper(f, **pickle_load_args)
#    1255 unpickler.persistent_load = persistent_load
# -> 1256 result = unpickler.load()
#    1258 deserialized_storage_keys = pickle_module.load(f, **pickle_load_args)
#    1260 offset = f.tell() if f_should_read_directly else None
#
# File ~/miniconda3/envs/KDW2V2-AASISTL/lib/python3.10/site-packages/torch/serialization.py:1061, in _legacy_load.<locals>.UnpicklerWrapper.find_class(self, mod_name, name)
#    1059     except KeyError:
#    1060         pass
# -> 1061 return super().find_class(mod_name, name)
#
# ModuleNotFoundError: No module named 'fairseq.meters'
